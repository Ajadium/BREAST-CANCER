# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
df = pd.read_csv('diabetes_dataset00.csv')

# %%
df.head()
# Out:
#                              Target Genetic Markers Autoantibodies  \
# 0          Steroid-Induced Diabetes        Positive       Negative
# 1  Neonatal Diabetes Mellitus (NDM)        Positive       Negative
# 2                       Prediabetic        Positive       Positive
# 3                   Type 1 Diabetes        Negative       Positive
# 4                  Wolfram Syndrome        Negative       Negative
#
#   Family History Environmental Factors  Insulin Levels  Age  BMI  \
# 0             No               Present              40   44   38
# 1             No               Present              13    1   17
# 2            Yes               Present              27   36   24
# 3             No               Present               8    7   16
# 4            Yes               Present              17   10   17
#
#   Physical Activity Dietary Habits  ...  Pulmonary Function  \
# 0              High        Healthy  ...                  76
# 1              High        Healthy  ...                  60
# 2              High      Unhealthy  ...                  80
# 3               Low      Unhealthy  ...                  89
# 4              High        Healthy  ...                  41
#
#    Cystic Fibrosis Diagnosis  Steroid Use History  Genetic Testing  \
# 0                         No                   No         Positive
# 1                        Yes                   No         Negative
# 2                        Yes                   No         Negative
# 3                        Yes                   No         Positive
# 4                         No                   No         Positive
#
#   Neurological Assessments Liver Function Tests Digestive Enzyme Levels  \
# 0                        3               Normal                      56
# 1                        1               Normal                      28
# 2                        1             Abnormal                      55
# 3                        2             Abnormal                      60
# 4                        1               Normal                      24
#
#         Urine Test Birth Weight Early Onset Symptoms
# 0  Ketones Present         2629                   No
# 1  Glucose Present         1881                  Yes
# 2  Ketones Present         3622                  Yes
# 3  Ketones Present         3542                   No
# 4  Protein Present         1770                   No
#
# [5 rows x 34 columns]

# %%
Label_encoders = {}
for col in df.columns:
    if df[col].dtype == 'object':
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
        Label_encoders[col] = le

# %%
x = df.drop('Target', axis= 1)
y  = df['Target']

# %%
X_train, x_temp, y_train, y_temp = train_test_split(x,y, test_size=0.4, random_state=42, stratify=y)
X_test, x_val, y_test, y_val = train_test_split(x_temp,y_temp, test_size=0.5, random_state=42, stratify=y_temp)

# %%
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)
x_val = scalar.transform(x_val)
x_test = scalar.transform(x_test)
# Out:
# c:\Users\USER\AppData\Local\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(len(set(y)), activation= 'sigmoid')

])

# %%
model.compile(optimizer = 'adam', loss= 'sparse_categorical_crossentropy', metrics= ['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(x_val, y_val))
# Out:
# Epoch 1/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.5598 - loss: 1.1890 - val_accuracy: 0.7404 - val_loss: 0.6301
# Epoch 2/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7543 - loss: 0.5878 - val_accuracy: 0.7611 - val_loss: 0.5777
# Epoch 3/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7739 - loss: 0.5487 - val_accuracy: 0.7726 - val_loss: 0.5469
# Epoch 4/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.7882 - loss: 0.5116 - val_accuracy: 0.7842 - val_loss: 0.5171
# Epoch 5/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.7981 - loss: 0.4890 - val_accuracy: 0.7931 - val_loss: 0.5020
# Epoch 6/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8065 - loss: 0.4703 - val_accuracy: 0.7987 - val_loss: 0.4925
# Epoch 7/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8100 - loss: 0.4621 - val_accuracy: 0.7963 - val_loss: 0.4941
# Epoch 8/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8133 - loss: 0.4439 - val_accuracy: 0.8034 - val_loss: 0.4717
# Epoch 9/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8193 - loss: 0.4332 - val_accuracy: 0.8035 - val_loss: 0.4710
# Epoch 10/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8283 - loss: 0.4177 - val_accuracy: 0.8071 - val_loss: 0.4689
# Epoch 11/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8301 - loss: 0.4141 - val_accuracy: 0.8114 - val_loss: 0.4569
# Epoch 12/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8290 - loss: 0.4045 - val_accuracy: 0.8115 - val_loss: 0.4583
# Epoch 13/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8369 - loss: 0.3947 - val_accuracy: 0.8133 - val_loss: 0.4487
# Epoch 14/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8432 - loss: 0.3845 - val_accuracy: 0.8128 - val_loss: 0.4517
# Epoch 15/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8419 - loss: 0.3835 - val_accuracy: 0.8178 - val_loss: 0.4438
# Epoch 16/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8461 - loss: 0.3751 - val_accuracy: 0.8181 - val_loss: 0.4426
# Epoch 17/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8435 - loss: 0.3760 - val_accuracy: 0.8177 - val_loss: 0.4458
# Epoch 18/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8490 - loss: 0.3646 - val_accuracy: 0.8223 - val_loss: 0.4386
# Epoch 19/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8524 - loss: 0.3604 - val_accuracy: 0.8189 - val_loss: 0.4405
# Epoch 20/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8527 - loss: 0.3561 - val_accuracy: 0.8251 - val_loss: 0.4296
# Epoch 21/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8524 - loss: 0.3516 - val_accuracy: 0.8234 - val_loss: 0.4268
# Epoch 22/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8547 - loss: 0.3474 - val_accuracy: 0.8286 - val_loss: 0.4183
# Epoch 23/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8570 - loss: 0.3417 - val_accuracy: 0.8264 - val_loss: 0.4258
# Epoch 24/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8584 - loss: 0.3383 - val_accuracy: 0.8310 - val_loss: 0.4229
# Epoch 25/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8636 - loss: 0.3278 - val_accuracy: 0.8282 - val_loss: 0.4194
# Epoch 26/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8599 - loss: 0.3299 - val_accuracy: 0.8311 - val_loss: 0.4145
# Epoch 27/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8650 - loss: 0.3241 - val_accuracy: 0.8266 - val_loss: 0.4266
# Epoch 28/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8651 - loss: 0.3171 - val_accuracy: 0.8319 - val_loss: 0.4077
# Epoch 29/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8721 - loss: 0.3116 - val_accuracy: 0.8291 - val_loss: 0.4259
# Epoch 30/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8691 - loss: 0.3136 - val_accuracy: 0.8347 - val_loss: 0.4194
# Epoch 31/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8677 - loss: 0.3120 - val_accuracy: 0.8285 - val_loss: 0.4155
# Epoch 32/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8720 - loss: 0.3026 - val_accuracy: 0.8263 - val_loss: 0.4163
# Epoch 33/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8746 - loss: 0.2994 - val_accuracy: 0.8306 - val_loss: 0.4142
# Epoch 34/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8723 - loss: 0.3037 - val_accuracy: 0.8286 - val_loss: 0.4108
# Epoch 35/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8759 - loss: 0.2905 - val_accuracy: 0.8289 - val_loss: 0.4151
# Epoch 36/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8773 - loss: 0.2901 - val_accuracy: 0.8363 - val_loss: 0.4200
# Epoch 37/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8767 - loss: 0.2915 - val_accuracy: 0.8322 - val_loss: 0.4203
# Epoch 38/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8800 - loss: 0.2865 - val_accuracy: 0.8329 - val_loss: 0.4145
# Epoch 39/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8787 - loss: 0.2870 - val_accuracy: 0.8325 - val_loss: 0.4079
# Epoch 40/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8810 - loss: 0.2849 - val_accuracy: 0.8384 - val_loss: 0.4074
# Epoch 41/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8785 - loss: 0.2807 - val_accuracy: 0.8357 - val_loss: 0.4068
# Epoch 42/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8864 - loss: 0.2743 - val_accuracy: 0.8338 - val_loss: 0.4225
# Epoch 43/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8857 - loss: 0.2716 - val_accuracy: 0.8344 - val_loss: 0.4183
# Epoch 44/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8827 - loss: 0.2732 - val_accuracy: 0.8326 - val_loss: 0.4164
# Epoch 45/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8857 - loss: 0.2711 - val_accuracy: 0.8374 - val_loss: 0.4180
# Epoch 46/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8836 - loss: 0.2706 - val_accuracy: 0.8351 - val_loss: 0.4125
# Epoch 47/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8886 - loss: 0.2669 - val_accuracy: 0.8346 - val_loss: 0.4123
# Epoch 48/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8885 - loss: 0.2671 - val_accuracy: 0.8359 - val_loss: 0.4098
# Epoch 49/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8870 - loss: 0.2629 - val_accuracy: 0.8317 - val_loss: 0.4180
# Epoch 50/50
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8906 - loss: 0.2616 - val_accuracy: 0.8376 - val_loss: 0.4105

# %%
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test_accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 438/438 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.0749 - loss: 3.4515
# Test_accuracy: 7.70%
